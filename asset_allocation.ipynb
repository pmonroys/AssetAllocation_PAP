# %% [markdown]
# PAP

# %%
import yfinance as yf
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

from AA import DataDownloader, AssetAllocation
# Out:
# C:\Users\pmonr\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\pmonr\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
downloader = DataDownloader()

assets = ['AAPL', 'IBM', 'TSLA', 'GOOG', 'NVDA'] 
benchmark = '^GSPC'  
start_date = '2019-01-01'
end_date = '2023-12-31'
rf = .065

asset_prices, benchmark_prices = downloader.download_data(start_date= start_date, end_date= end_date,
                                                          assets= assets, benchmark=benchmark)


# Default limits for every asset (min 1% - max 100%):  boounds = tuple((0.01, 1) for _ in range(self.num_assets))
Asset_allocation = AssetAllocation(asset_prices = asset_prices,benchmark_prices = benchmark_prices, rf=rf)
# Out:
# [*********************100%%**********************]  5 of 5 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
Asset_allocation.Optimize_Portfolio(n_simulations = 10000) #Default Method == "Montecarlo"
# Out:
# Ticker                    AAPL      GOOG       IBM      NVDA      TSLA  \
# Max Sharpe            0.134374  0.013523  0.025583  0.576370  0.250149
# Max Omega             0.035434  0.016094  0.028839  0.889600  0.030032
# Min VaR (Empirical)   0.011892  0.042956  0.048234  0.068077  0.828840
# Min VaR (Parametric)  0.130934  0.205070  0.625734  0.010036  0.028227
# Semivariance          0.198861  0.210839  0.560452  0.017773  0.012076
# Max Sortino           0.021372  0.026421  0.011708  0.888999  0.051500
# Risk Parity           0.046324  0.022928  0.052300  0.049972  0.828476
#
# Ticker                Optimized Value
# Max Sharpe                   0.079780
# Max Omega                    1.274502
# Min VaR (Empirical)         -0.052603
# Min VaR (Parametric)        -0.024488
# Semivariance                 0.000223
# Max Sortino                  0.053742
# Risk Parity                  0.000883

# %%
Asset_allocation.Optimize_Portfolio(method = "SLSQP")
# Out:
# Ticker                    AAPL      GOOG       IBM      NVDA      TSLA  \
# Max Sharpe            0.221458  0.010000  0.010000  0.501680  0.256863
# Max Omega             0.010000  0.010000  0.010000  0.960000  0.010000
# Min VaR (Empirical)   0.010000  0.010000  0.010000  0.389194  0.580806
# Min VaR (Parametric)  0.156483  0.217158  0.606359  0.010000  0.010000
# Semivariance          0.200000  0.200000  0.200000  0.200000  0.200000
# Max Sortino           0.010000  0.010000  0.010000  0.859137  0.110863
# Risk Parity           0.200000  0.200000  0.200000  0.200000  0.200000
#
# Ticker                Optimized Value
# Max Sharpe                   0.079996
# Max Omega                    1.288639
# Min VaR (Empirical)         -0.049680
# Min VaR (Parametric)        -0.024424
# Semivariance                 0.000401
# Max Sortino                  0.054139
# Risk Parity                  0.000014

# %%
Asset_allocation.Optimize_Portfolio(method = "Genetic", population_size=100, generations=200, crossover_rate=0.7, mutation_rate=0.1)
# Out:
# Ticker                    AAPL      GOOG       IBM      NVDA      TSLA  \
# Max Sharpe            0.199890  0.043360  0.051006  0.536036  0.169709
# Max Omega             0.159272  0.009328  0.008479  0.470268  0.352653
# Min VaR (Empirical)   0.047031  0.255601  0.050332  0.117965  0.529070
# Min VaR (Parametric)  0.221157  0.277549  0.281806  0.204177  0.015311
# Semivariance          0.305526  0.068940  0.355925  0.023945  0.245665
# Max Sortino           0.103610  0.054452  0.049328  0.415538  0.377071
# Risk Parity           0.013561  0.036024  0.026002  0.017809  0.906604
#
# Ticker                Optimized Value
# Max Sharpe                   0.078909
# Max Omega                    1.210434
# Min VaR (Empirical)         -0.045623
# Min VaR (Parametric)        -0.027729
# Semivariance                 0.000339
# Max Sortino                  0.051022
# Risk Parity                  0.001078

# %%
Asset_allocation.Optimize_Portfolio(method = "Gradient", learning_rate=0.01, max_iters=1000, tol=1e-6)
# Out:
# Ticker                    AAPL      GOOG       IBM      NVDA      TSLA  \
# Max Sharpe            0.218456  0.079268  0.141724  0.316454  0.244097
# Max Omega             0.205361  0.189996  0.174982  0.229846  0.199815
# Min VaR (Empirical)   0.199397  0.201444  0.199150  0.196247  0.203763
# Min VaR (Parametric)  0.255781  0.282328  0.441872  0.010009  0.010009
# Semivariance          0.200001  0.200002  0.200005  0.199997  0.199995
# Max Sortino           0.194234  0.102213  0.091345  0.330213  0.281995
# Risk Parity           0.199999  0.199999  0.199999  0.200001  0.200002
#
# Ticker                Optimized Value
# Max Sharpe                   0.077620
# Max Omega                    1.137665
# Min VaR (Empirical)         -0.035712
# Min VaR (Parametric)        -0.022531
# Semivariance                 0.000401
# Max Sortino                  0.048727
# Risk Parity                  0.000014

# %% [markdown]
# -----

# %% [markdown]
# -------

# %% [markdown]
# --------------

# %% [markdown]
# ----------
